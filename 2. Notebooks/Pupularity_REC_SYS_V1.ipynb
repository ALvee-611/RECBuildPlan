# %% [markdown]
# # Popularity Based Recommender System

# %%
import os
import pandas as pd
import configparser
#import mysql.connector
from sqlalchemy import create_engine

import seaborn as sns
import matplotlib.pyplot as plt

config = configparser.ConfigParser()
config.read('..\\config.ini')

host = config['mysql']['host']
database = config['mysql']['database']
user = config['mysql']['user']
password = config['mysql']['password']
port = config['mysql']['port']

def read_query(query):
    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
    df = pd.read_sql(query, con=engine)
    print('Query Executed!')
    return df

# %% [markdown]
# Finding the most Popular item on weekday and weekend respectively:

# %% [markdown]
# To 5 items for a weekday:

# %%
q = """
SELECT 
    article_id, MAX(total_purchases) AS most_popular
FROM
    popularity_v1
WHERE
    day_type = 'weekday'
GROUP BY article_id
ORDER BY most_popular DESC
LIMIT 5;
"""

read_query(q)
# Out:
# Query Executed!
#   article_id  most_popular
# 0  706016001       30423.0
# 1  706016002       20513.0
# 2  706016003       14290.0
# 3  448509014       13496.0
# 4  562245001       12826.0

# %% [markdown]
# To 5 items for a weekend:

# %%
q = """
SELECT 
    article_id, MAX(total_purchases) AS most_popular
FROM
    popularity_v1
WHERE
    day_type = 'weekend'
GROUP BY article_id
ORDER BY most_popular DESC
LIMIT 5;
"""

read_query(q)
# Out:
# Query Executed!
#   article_id  most_popular
# 0  706016001       12121.0
# 1  706016002        8779.0
# 2  562245001        6636.0
# 3  706016003        5591.0
# 4  351484002        5392.0

# %% [markdown]
# We will first build out the recommender system that recoomends the top 5 most popular items based on if the day is a weekday or weekend by using the most_popular items for that day in the past.

# %%
day = 'weekend'

if day == "weekday":
    q = """
    SELECT 
        article_id, MAX(total_purchases) AS most_popular
    FROM
        popularity_v1
    WHERE
        day_type = 'weekday'
    GROUP BY article_id
    ORDER BY most_popular DESC
    LIMIT 5;
    """
else:
    q = """
    SELECT 
    article_id, MAX(total_purchases) AS most_popular
    FROM
        popularity_v1
    WHERE
        day_type = 'weekend'
    GROUP BY article_id
    ORDER BY most_popular DESC
    LIMIT 5;
    """

result = read_query(q)

result
# Out:
# Query Executed!
#   article_id  most_popular
# 0  706016001       12121.0
# 1  706016002        8779.0
# 2  562245001        6636.0
# 3  706016003        5591.0
# 4  351484002        5392.0

# %%
import matplotlib.image as mpimg

# %% [markdown]
# Once we have the top 5 products we will use the article_id to retireve the image of the product:

# %%
location_of_subfolders = "..//h-and-m-personalized-fashion-recommendations//images"


all_articles = []

for i in result['article_id']:
    # get first 2 letters of the name and get subfolder name:
    folder_name = '0' + i[:2]

    location_of_images = os.path.join(location_of_subfolders, folder_name)
    image_names = '0' + i + '.jpg'
    image_location = os.path.join(location_of_images, image_names)

    # Load the image from image location
    img = mpimg.imread(image_location)

    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# Saving all ina function:

# %%
def dispaly_images(article_list):
    """
        article_list is a list of all the ids of the articles we want to retrieve
    """
    # Subfolder containing the images
    location_of_subfolders = "..//h-and-m-personalized-fashion-recommendations//images"

    for i in article_list:
        # get first 2 letters of the name and get subfolder name:
        folder_name = '0' + i[:2]

        location_of_images = os.path.join(location_of_subfolders, folder_name)
        image_names = '0' + i + '.jpg'
        image_location = os.path.join(location_of_images, image_names)

        # Load the image from image location
        img = mpimg.imread(image_location)

        plt.imshow(img)
        plt.axis('off')
        plt.show()

# %% [markdown]
# From looking at the results one issue we can notice is that the top 4 results are all jeans and they seem to all look the same! So instead of showing just jeans as recommended products, we can get more information about each product and then group them so that we get some more variety.
#
# In `articles_EDA` notebook we already explored the features available for each product so we can now get the relevant features for each product here:

# %%
q = """
SELECT 
    P.article_id,
    P.total_purchases,
    P.day_type,
    A.prod_name,
    A.product_type_name,
    A.product_group_name,
    A.department_name,
    A.section_name,
    A.garment_group_name,
    A.index_group_name
FROM
    popularity_v1 P,
    articles A
WHERE
    P.article_id = A.article_id;
"""

read_query(q)
# Out:
# Query Executed!
#        article_id  total_purchases day_type               prod_name
# 0       211143037            366.0  weekday        Janet SL-set (W)  \
# 1       255396006             77.0  weekday           Nora Cardigan
# 2       294008002           2809.0  weekday            HM+ Cora tee
# 3       176550020             40.0  weekday        Sleep bag padded
# 4       212629040            305.0  weekday     Alcazar strap dress
# ...           ...              ...      ...                     ...
# 185097  850795002              4.0  weekday               Sun skirt
# 185098  910439003              7.0  weekday  Petit Madison HW denim
# 185099  903950001              7.0  weekday           Riga trousers
# 185100  880553004              4.0  weekday       OP NEW Perth Push
# 185101  578752006              1.0  weekday    PLUS Heavy Plain 2 p
#
#        product_type_name   product_group_name    department_name
# 0             Pyjama set            Nightwear          Nightwear  \
# 1               Cardigan   Garment Upper body    Jersey Fancy DS
# 2               Costumes    Garment Full body             Jersey
# 3              Sleep Bag  Underwear/nightwear     Baby Nightwear
# 4                  Dress    Garment Full body            Basic 1
# ...                  ...                  ...                ...
# 185097             Skirt   Garment Lower body  Kids Girl Dresses
# 185098          Trousers   Garment Lower body            Trouser
# 185099          Trousers   Garment Lower body         Loungewear
# 185100           Unknown              Unknown     Clean Lingerie
# 185101  Underwear Tights       Socks & Tights       Tights basic
#
#                           section_name    garment_group_name index_group_name
# 0       Womens Nightwear, Socks & Tigh     Under-, Nightwear       Ladieswear
# 1                     Divided Selected          Jersey Fancy          Divided
# 2                                 H&M+          Jersey Fancy       Ladieswear
# 3        Baby Essentials & Complements     Under-, Nightwear    Baby/Children
# 4                       Divided Basics          Jersey Basic          Divided
# ...                                ...                   ...              ...
# 185097                       Kids Girl  Dresses/Skirts girls    Baby/Children
# 185098      Womens Everyday Collection              Trousers       Ladieswear
# 185099  Womens Nightwear, Socks & Tigh     Under-, Nightwear       Ladieswear
# 185100                 Womens Lingerie     Under-, Nightwear       Ladieswear
# 185101  Womens Nightwear, Socks & Tigh      Socks and Tights       Ladieswear
#
# [185102 rows x 10 columns]
